# %%
import pandas as pd
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt
import geopandas

# %%
schools = pd.read_csv("neighborhood_enrollment.csv")

# %%
aa_mean = schools["african_american"].mean()
ai_mean = schools["american_indian"].mean()
ap_mean = schools["asian__not_pacific_islander"].mean()
h_mean = schools["hispanic"].mean()

# %%
print(aa_mean)
print(ai_mean)
print(ap_mean)
print(h_mean)
# Out:
# 59.94054054054054
# nan
# 26.63157894736842
# 23.866666666666667

# %%
enroll = schools[["neighborhood", ["total_students_enrolled"] > 1]]
enroll.sort_values(by="total_students_enrolled")
enroll.head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-cd4ba3251029> in <module>
# ----> 1 enroll = schools[["neighborhood", ["total_students_enrolled"] > 1]]
#       2 enroll.sort_values(by="total_students_enrolled")
#       3 enroll.head(10)
#
# TypeError: '>' not supported between instances of 'list' and 'int'

# %%
schools.dropna(subset = "total_students_enrolled")
# Out:
#             neighborhood  african_american  american_indian  \
# 6      Bedford Dwellings              12.0              NaN
# 7              Beechview               NaN              NaN
# 9             Bloomfield               NaN              NaN
# 12      Brighton Heights              23.0              NaN
# 13             Brookline               NaN              NaN
# ..                   ...               ...              ...
# 354  Upper Lawrenceville               NaN              NaN
# 356         West Oakland              13.0              NaN
# 357             Westwood               NaN              NaN
# 358  Wilkinsburg Borough             178.0              NaN
# 359              Windgap              19.0              NaN
#
#      asian__not_pacific_islander  hispanic  multiracial  \
# 6                            NaN       NaN          NaN
# 7                            NaN      13.0          NaN
# 9                            NaN       NaN          NaN
# ...

# %%
students = schools[["neighborhood", "total_students_enrolled", "grade_level"]]
students.head(10)
# Out:
#         neighborhood  total_students_enrolled grade_level
# 0   Allegheny Center                      NaN       Pre-K
# 1     Allegheny West                      NaN       Pre-K
# 2          Allentown                      NaN       Pre-K
# 3          Arlington                      NaN       Pre-K
# 4  Arlington Heights                      NaN       Pre-K
# 5         Banksville                      NaN       Pre-K
# 6  Bedford Dwellings                     12.0       Pre-K
# 7          Beechview                     44.0       Pre-K
# 8        Beltzhoover                      NaN       Pre-K
# 9         Bloomfield                     21.0       Pre-K
